# %% [markdown]
# ## Airports
# Data Source: https://data.world/datagov-uk/2ecd2a35-fc85-4cd9-b1e7-3a8f92d76fd7

# %%
import pandas as pd
import os
import json
import requests
from pprint import pprint

# %%
file = os.path.join('airports_all_2015.csv')
airports_df = pd.read_csv(file)
airports_df.head()
# Out:
#    Rank                                           Airport    Location  \
# 0     1  Hartsfield-Jackson Atlanta International Airport  Atlanta GA
# 1     2             Beijing Capital International Airport     Beijing
# 2     3                       Dubai International Airport       Dubai
# 3     4                      O'Hare International Airport  Chicago IL
# 4     5              Tokyo International (Haneda) Airport       Tokyo
#
#                               Country Code (IATA/ICAO) Total passengers  \
# 0                                 USA              ATL     101,491,106
# 1  China (People's Republic of China)              PEK      89,938,628
# 2                United Arab Emirates              DXB      78,014,841
# 3                                 USA              ORD      76,949,504
# 4                               Japan              HND      75,573,106
#
#    % change
# 0       5.5
# 1       4.4
# 2      10.7
# 3       9.8
# 4       3.8

# %%
def lat_long(iata):

    url = "https://cometari-airportsfinder-v1.p.rapidapi.com/api/airports/by-code"

    querystring = {"code": f"{iata}"}

    headers = {
        'x-rapidapi-host': "cometari-airportsfinder-v1.p.rapidapi.com",
        'x-rapidapi-key': "8cc177b195msh4e4f4ff4e0cae0fp10ed89jsn60e0207e5c4d"
        }

    response = requests.get(url, headers=headers, params=querystring).json()

    latitude = response[0]['location']['latitude']
    longitude = response[0]['location']['longitude']

    return latitude, longitude

# %%
# Find Latitude and Longitude of each airport
lat_list = []
long_list = []

for i in range(len(airports_df)):
    iata = airports_df['Code (IATA/ICAO)'][i]
    latitude, longitude = lat_long(iata)
    lat_list.append(latitude)
    long_list.append(longitude)
# Out:
# ATL
# PEK
# DXB
# ORD
# HND
# LHR
# LAX
# HKG
# CDG
# DFW
# IST
# FRA
# PVG
# AMS
# JFK
# SIN
# CAN
# CGK
# DEN
# BKK
# SFO
# ICN
# KUL
# MAD
# DEL
# LAS
# CLT
# MIA
# PHX
# IAH
# SEA
# CTU
# YYZ
# MUC
# BOM
# FCO
# LGW
# SYD
# SZX
# BCN
# GRU
# SHA
# MCO
# TPE
# MEX
# KMG
# EWR
# NRT
# MNL
# MSP

# %%
# Add lat, long to dataframe
airports_df['Lat'] = lat_list
airports_df['Long'] = long_list
airports_df.dropna(inplace=True)
# airports.head()

# %%
# Check if each airport is international
file = os.path.join('airports_intl_2016.csv')
intl_df = pd.read_csv(file)
# intl_df.head()

intl = intl_df['Code (IATA/ICAO)']
intl_bool = []

for index, row in airports_df.iterrows():
    iata = row['Code (IATA/ICAO)']
    if iata in intl.unique():
        intl_bool.append("International")
    else:
        intl_bool.append("Domestic")

airports_df['Type'] = intl_bool
airports_df.head()
# Out:
#    Rank                              Airport   Location Code (IATA/ICAO)  \
# 0   1.0          Dubai International Airport      DUBAI              DXB
# 1   2.0                     Heathrow Airport     LONDON              LHR
# 2   3.0      Hong Kong International Airport  HONG KONG              HKG
# 3   4.0  Aéroport de Paris-Charles de Gaulle      PARIS              CDG
# 4   5.0                    Amsterdam Airport  AMSTERDAM              AMS
#
#   Total passengers  % change
# 0      77 453 466       10.7
# 1      69 816 491        2.5
# 2      68 139 897        8.3
# 3      60 369 798        3.0
# 4      58 245 545        6.0

# %%
file = os.path.join('airports.csv')
airports_df.to_csv(file, index=False, header=True)
